# %% [markdown]
# # Pandas
#
# Think of pandas as an extremely powerful version of Excel, with a lot more feature.
#
# + Series : we can see is actually a numpy array but with a label
# (sometime called label & index)
# + DataFrames

# %%
import numpy as np
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
labels = list("abc")
my_list = [10,20,30]

arr = np.array(my_list)
d = {'a': 10, 'b': 20, 'c': 30}

# %%
pd.Series(data = my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series((10,20,30))
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
type(pd.Series((10,20,30)))
# Out:
# pandas.core.series.Series

# %%
labels
# Out:
# ['a', 'b', 'c']

# %%
pd.Series(data= my_list, index = labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(data = d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
labels = list("aab")

# %%
labels
# Out:
# ['a', 'a', 'b']

# %%
ser = pd.Series(my_list, labels)

# %%
ser
# Out:
# a    10
# a    20
# b    30
# dtype: int64

# %%
ser['b']
# Out:
# np.int64(30)

# %%
ser['a']
# Out:
# a    10
# a    20
# dtype: int64

# %%
t = pd.Series(my_list, [1,True,[1,2]])

# %%
t
# Out:
# 1         10
# True      20
# [1, 2]    30
# dtype: int64

# %%
t[[1,2]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 t[[1,2]]
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/series.py:1153, in Series.__getitem__(self, key)
#    1150     key = np.asarray(key, dtype=bool)
#    1151     return self._get_rows_with_mask(key)
# -> 1153 return self._get_with(key)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/series.py:1180, in Series._get_with(self, key)
#    1176 if key_type == "integer":
#    1177     # We need to decide whether to treat this as a positional indexer
#    1178     #  (i.e. self.iloc) or label-based (i.e. self.loc)
#    1179     if not self.index._should_fallback_to_positional:
# -> 1180         return self.loc[key]
#    1181     else:
#    1182         warnings.warn(
#    1183             # GH#50617
# ...

# %%
t = pd.Series(my_list, [1, True, (1,2,3)])

# %%
t
# Out:
# 1            10
# True         20
# (1, 2, 3)    30
# dtype: int64

# %%
ser1 = pd.Series([1,2,3], list("abc"))

# %%
ser1
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
ser2 = pd.Series([4,5,6,7], list("abcf"))

# %%
ser
# Out:
# a    10
# a    20
# b    30
# dtype: int64

# %%
ser1 + ser2
# Out:
# a    5.0
# b    7.0
# c    9.0
# f    NaN
# dtype: float64

# %%
ser2 = pd.Series([4,5,6], list('bac'))

# %%
ser2
# Out:
# b    4
# a    5
# c    6
# dtype: int64

# %%
ser1
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
ser1 + ser2
# Out:
# a    6
# b    6
# c    9
# dtype: int64

# %%
ser2 = pd.Series([4,5,6], list("cbd"))

# %%
ser1 + ser2
# Out:
# a    NaN
# b    7.0
# c    7.0
# d    NaN
# dtype: float64
